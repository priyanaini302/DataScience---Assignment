# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Replacing nun values

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # Not placed students counts

# %%
not_placed=[]
for i in (dataset['status']):
    if i=='Not Placed':
        not_placed.append(i)

# %%
len(not_placed)
# Out:
# 67

# %% [markdown]
# #Total 67 members not placed

# %% [markdown]
# # Reson for not placing students

# %%
no=dataset[dataset['status']=='Not Placed']

# %%
no
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# # Relation between salary and mba

# %%
print(dataset['salary'].corr(dataset['mba_p']))
# Out:
# 0.13982273892615565

# %% [markdown]
# # Which specialization getting min salary

# %%
spl=dataset[dataset['salary']==200000]

# %%
spl
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 15      16      F  65.00  Central  75.00  Central  Commerce     69.00
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 15   Comm&Mgmt    Yes     72.0        Mkt&Fin  64.66  Placed  200000.0
# 44   Comm&Mgmt    Yes     89.0        Mkt&Fin  69.70  Placed  200000.0
# 50   Comm&Mgmt     No     65.0         Mkt&HR  62.98  Placed  200000.0
# 107  Comm&Mgmt     No     80.0         Mkt&HR  73.52  Placed  200000.0
# ...

# %%
# Sci&Tech,Comm&Mgmt specilization getting minimum salary

# %% [markdown]
# # how many of them getting high salary

# %%
for i in dataset['salary']:
    #print(i)
    if i>=500000.0:
        print(i)
# Out:
# 500000.0
# 940000.0
# 690000.0
# 500000.0
# 500000.0
# 650000.0

# %%
# totally 6 members getting high salary

# %% [markdown]
# # Analysis varience between etest_p and mba_p (hypothis testing significant=5%)

# %%
from scipy.stats import stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
# pvalue is more than significant value so reject null hypothis and acept alternative hypothis

# %% [markdown]
# # Similarity between degree('Sci&Tech') and specilization (Mkt&HR)

# %%
from scipy.stats import ttest_ind
n1=dataset[dataset['degree_t']=='Sci&Tech']['salary']
n2=dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(n1,n2)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %%
# pvalue is less than significant value so reject alternative hypothis and acept null hypothis

# %% [markdown]
# # Normal distibution into standard Normal distribution

# %%
dataset1=pd.read_csv("Pre_processdata.csv")
dataset1
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
import seaborn as sns
sns.distplot(dataset1['salary'])
# Out:
# C:\Users\Priya\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
def std_fun(dataset1):
    mean=dataset1.mean()
    std=dataset1.std()
    values=[value for value in dataset1]
    z_score=[((j-mean)/std) for j in values]
    sns.distplot(z_score,kde=True)

# %%
std_fun(dataset1['salary'])
# Out:
# C:\Users\Priya\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# # probability density function

# %%
from matplotlib import pyplot
from scipy.stats import norm
def pdf_prob(dataset1,startrange,endrange):
    ax=sns.distplot(dataset1,kde=True,kde_kws={'color':'blue'},color='green')
    pyplot.axvline(startrange,color='red')
    pyplot.axvline(endrange,color='red')
    sample=dataset1
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('mean={},Standard Deviation={}'.format(sample_mean, sample_std))
    dist=norm(sample_mean,sample_std)
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print('The area between range ({},{}):{}'.format(startrange,endrange,prob))
    return prob

# %%
pdf_prob(dataset1['salary'],700000,900000)
# Out:
# C:\Users\Priya\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   after removing the cwd from sys.path.
# mean=288655.40540540544,Standard Deviation=77457.90010195275
# The area between range (700000,900000):5.4647277868994836e-08
# 5.4647277868994836e-08

# %%
# Similarity between degree('Sci&Tech') with mba_p and etest_p

# %%
from scipy.stats import ttest_rel
test1=dataset1[dataset1['degree_t']=='Sci&Tech']['etest_p']
test2=dataset1[dataset1['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(test1,test2)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %%
# pvalue is more than significant value so reject null hypothis  and acept alternative hypothis

# %% [markdown]
# # highly correlated cloumns

# %%
dataset1.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.051550
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.023571
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.054506
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.014148
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.152829
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.146324
# salary    0.051550  0.023571  0.054506 -0.014148  0.152829  0.146324  1.000000

# %%
# ssc_p is highly correlated with salary
